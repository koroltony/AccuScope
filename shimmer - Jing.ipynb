# %%
import cv2
import numpy as np

def detect_shimmering_brightness_weighted(video_path, threshold=30, frame_interval=14):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    prev_frame = None
    shimmer_timestamps = []

    # Get the frames per second (FPS) to calculate timestamps
    fps = cap.get(cv2.CAP_PROP_FPS)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1

        # Convert frame to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        if prev_frame is not None:
            # Calculate absolute difference between current frame and previous frame
            diff = cv2.absdiff(prev_frame, gray_frame)

            # Use a brightness-weighted approach
            weighted_diff = diff * (gray_frame / 255.0)

            # Detect changes above the threshold
            _, diff_thresh = cv2.threshold(weighted_diff.astype(np.uint8), threshold, 255, cv2.THRESH_BINARY)

            # Calculate the percentage of weighted pixels that have changed
            change_percentage = (np.sum(diff_thresh) / (diff_thresh.size * 255)) * 100

            if change_percentage > 0.5:  # Adjust the percentage threshold as needed
                # Calculate the timestamp in seconds
                timestamp = frame_count / fps
                shimmer_timestamps.append(timestamp)

        # Update previous frame every 'frame_interval' frames
        if frame_count % frame_interval == 0:
            prev_frame = gray_frame

    cap.release()

    # Output shimmer timestamps
    for timestamp in shimmer_timestamps:
        print(f"Shimmer detected at {timestamp:.2f} seconds")

    print("Detection completed.")

# Usage example
detect_shimmering_brightness_weighted(r"C:\Users\surface\Desktop\Arthrex\HDR shimmer coracoid.mp4")
# Out:
# Shimmer detected at 0.30 seconds
# Shimmer detected at 0.32 seconds
# Shimmer detected at 0.34 seconds
# Shimmer detected at 0.44 seconds
# Shimmer detected at 0.46 seconds
# Shimmer detected at 0.47 seconds
# Shimmer detected at 0.54 seconds
# Shimmer detected at 0.56 seconds
# Shimmer detected at 0.57 seconds
# Shimmer detected at 0.59 seconds
# Shimmer detected at 0.61 seconds
# Shimmer detected at 0.62 seconds
# Shimmer detected at 0.64 seconds
# Shimmer detected at 0.66 seconds
# Shimmer detected at 0.67 seconds
# Shimmer detected at 0.69 seconds
# Shimmer detected at 0.71 seconds
# Shimmer detected at 0.74 seconds
# Shimmer detected at 0.76 seconds
# Shimmer detected at 0.78 seconds
# Shimmer detected at 0.79 seconds
# Shimmer detected at 0.81 seconds
# Shimmer detected at 0.83 seconds
# Shimmer detected at 0.84 seconds
# Shimmer detected at 0.86 seconds
# Shimmer detected at 0.88 seconds
# Shimmer detected at 0.89 seconds
# Shimmer detected at 0.91 seconds
# Shimmer detected at 0.93 seconds
# Shimmer detected at 0.94 seconds
# Shimmer detected at 1.00 seconds
# Shimmer detected at 1.01 seconds
# Shimmer detected at 1.03 seconds
# Shimmer detected at 1.05 seconds
# Shimmer detected at 1.06 seconds
# Shimmer detected at 1.08 seconds
# Shimmer detected at 1.10 seconds
# Shimmer detected at 1.11 seconds
# Shimmer detected at 1.13 seconds
# Shimmer detected at 1.15 seconds
# Shimmer detected at 1.16 seconds
# Shimmer detected at 1.18 seconds
# Shimmer detected at 1.26 seconds
# Shimmer detected at 1.28 seconds
# Shimmer detected at 1.30 seconds
# Shimmer detected at 1.32 seconds
# Shimmer detected at 1.33 seconds
# Shimmer detected at 1.35 seconds
# Shimmer detected at 1.37 seconds
# Shimmer detected at 1.38 seconds
# Shimmer detected at 1.40 seconds
# Shimmer detected at 1.42 seconds
# Shimmer detected at 1.45 seconds
# Shimmer detected at 1.47 seconds
# Shimmer detected at 1.48 seconds
# Shimmer detected at 1.50 seconds
# Shimmer detected at 1.52 seconds
# Shimmer detected at 1.53 seconds
# Shimmer detected at 1.55 seconds
# Shimmer detected at 1.57 seconds
# Shimmer detected at 1.59 seconds
# Shimmer detected at 1.60 seconds
# Shimmer detected at 1.62 seconds
# Shimmer detected at 1.64 seconds
# Shimmer detected at 1.65 seconds
# Shimmer detected at 1.69 seconds
# Shimmer detected at 1.70 seconds
# Shimmer detected at 1.72 seconds
# Shimmer detected at 1.74 seconds
# Shimmer detected at 1.75 seconds
# Shimmer detected at 1.77 seconds
# Shimmer detected at 1.79 seconds
# Shimmer detected at 1.80 seconds
# Shimmer detected at 1.82 seconds
# Shimmer detected at 1.84 seconds
# Shimmer detected at 1.86 seconds
# Shimmer detected at 1.87 seconds
# Shimmer detected at 1.89 seconds
# Shimmer detected at 2.02 seconds
# Shimmer detected at 2.04 seconds
# Shimmer detected at 2.06 seconds
# Shimmer detected at 2.07 seconds
# Shimmer detected at 2.09 seconds
# Shimmer detected at 2.11 seconds
# Shimmer detected at 2.12 seconds
# Shimmer detected at 2.18 seconds
# Shimmer detected at 2.19 seconds
# Shimmer detected at 2.21 seconds
# Shimmer detected at 2.23 seconds
# Shimmer detected at 2.24 seconds
# Shimmer detected at 2.26 seconds
# Shimmer detected at 2.28 seconds
# Shimmer detected at 2.29 seconds
# Shimmer detected at 2.31 seconds
# Shimmer detected at 2.33 seconds
# Shimmer detected at 2.34 seconds
# Shimmer detected at 2.36 seconds
# Shimmer detected at 2.75 seconds
# Shimmer detected at 2.77 seconds
# Shimmer detected at 6.98 seconds
# Shimmer detected at 7.00 seconds
# Shimmer detected at 7.02 seconds
# Shimmer detected at 7.03 seconds
# Shimmer detected at 7.05 seconds
# Shimmer detected at 7.07 seconds
# Shimmer detected at 7.08 seconds
# Shimmer detected at 7.12 seconds
# Shimmer detected at 7.13 seconds
# Shimmer detected at 7.15 seconds
# Shimmer detected at 7.17 seconds
# Shimmer detected at 7.18 seconds
# Shimmer detected at 7.20 seconds
# Shimmer detected at 7.22 seconds
# Shimmer detected at 7.23 seconds
# Shimmer detected at 7.25 seconds
# Shimmer detected at 7.27 seconds
# Shimmer detected at 7.29 seconds
# Shimmer detected at 7.30 seconds
# Shimmer detected at 7.32 seconds
# Shimmer detected at 7.35 seconds
# Shimmer detected at 7.37 seconds
# Shimmer detected at 7.39 seconds
# Shimmer detected at 7.40 seconds
# Shimmer detected at 7.42 seconds
# Shimmer detected at 7.44 seconds
# Shimmer detected at 7.45 seconds
# Shimmer detected at 7.47 seconds
# Shimmer detected at 7.49 seconds
# Shimmer detected at 7.50 seconds
# Shimmer detected at 7.52 seconds
# Shimmer detected at 7.54 seconds
# Shimmer detected at 7.56 seconds
# Shimmer detected at 7.77 seconds
# Shimmer detected at 7.79 seconds
# Shimmer detected at 7.93 seconds
# Shimmer detected at 7.94 seconds
# Shimmer detected at 7.96 seconds
# Shimmer detected at 7.98 seconds
# Shimmer detected at 7.99 seconds
# Shimmer detected at 8.01 seconds
# Shimmer detected at 8.03 seconds
# Shimmer detected at 8.06 seconds
# Shimmer detected at 8.08 seconds
# Shimmer detected at 8.09 seconds
# Shimmer detected at 8.11 seconds
# Shimmer detected at 8.13 seconds
# Shimmer detected at 8.15 seconds
# Shimmer detected at 8.16 seconds
# Shimmer detected at 8.18 seconds
# Shimmer detected at 8.20 seconds
# Shimmer detected at 8.21 seconds
# Shimmer detected at 8.23 seconds
# Shimmer detected at 8.25 seconds
# Shimmer detected at 8.26 seconds
# Shimmer detected at 8.36 seconds
# Shimmer detected at 8.38 seconds
# Shimmer detected at 8.40 seconds
# Shimmer detected at 8.42 seconds
# Shimmer detected at 8.43 seconds
# Shimmer detected at 8.45 seconds
# Shimmer detected at 8.47 seconds
# Shimmer detected at 8.48 seconds
# Shimmer detected at 8.50 seconds
# Shimmer detected at 9.63 seconds
# Shimmer detected at 9.65 seconds
# Shimmer detected at 9.66 seconds
# Shimmer detected at 9.68 seconds
# Shimmer detected at 9.83 seconds
# Shimmer detected at 9.85 seconds
# Shimmer detected at 9.87 seconds
# Shimmer detected at 9.88 seconds
# Shimmer detected at 9.90 seconds
# Shimmer detected at 9.92 seconds
# Shimmer detected at 10.73 seconds
# Shimmer detected at 10.74 seconds
# Shimmer detected at 10.76 seconds
# Shimmer detected at 10.78 seconds
# Shimmer detected at 10.79 seconds
# Shimmer detected at 10.81 seconds
# Shimmer detected at 10.83 seconds
# Shimmer detected at 10.84 seconds
# Shimmer detected at 10.86 seconds
# Shimmer detected at 15.50 seconds
# Shimmer detected at 15.52 seconds
# Shimmer detected at 15.53 seconds
# Shimmer detected at 15.55 seconds
# Shimmer detected at 15.57 seconds
# Shimmer detected at 15.58 seconds
# Shimmer detected at 15.60 seconds
# Shimmer detected at 15.62 seconds
# Shimmer detected at 15.63 seconds
# Shimmer detected at 15.65 seconds
# Shimmer detected at 15.67 seconds
# Shimmer detected at 15.68 seconds
# Shimmer detected at 15.70 seconds
# Shimmer detected at 15.72 seconds
# Shimmer detected at 15.73 seconds
# Shimmer detected at 15.75 seconds
# Shimmer detected at 15.77 seconds
# Shimmer detected at 15.79 seconds
# Shimmer detected at 15.80 seconds
# Shimmer detected at 15.82 seconds
# Shimmer detected at 16.44 seconds
# Shimmer detected at 16.46 seconds
# Shimmer detected at 16.48 seconds
# Shimmer detected at 16.49 seconds
# Shimmer detected at 16.51 seconds
# Shimmer detected at 16.53 seconds
# Shimmer detected at 16.97 seconds
# Shimmer detected at 17.12 seconds
# Shimmer detected at 17.13 seconds
# Shimmer detected at 17.15 seconds
# Shimmer detected at 17.17 seconds
# Shimmer detected at 17.18 seconds
# Shimmer detected at 17.20 seconds
# Shimmer detected at 17.22 seconds
# Shimmer detected at 17.24 seconds
# Shimmer detected at 17.32 seconds
# Shimmer detected at 17.34 seconds
# Shimmer detected at 17.35 seconds
# Shimmer detected at 17.37 seconds
# Shimmer detected at 17.39 seconds
# Shimmer detected at 17.40 seconds
# Shimmer detected at 17.42 seconds
# Shimmer detected at 17.44 seconds
# Shimmer detected at 17.45 seconds
# Shimmer detected at 17.47 seconds
# Shimmer detected at 17.69 seconds
# Shimmer detected at 17.71 seconds
# Shimmer detected at 17.83 seconds
# Shimmer detected at 17.84 seconds
# Shimmer detected at 17.86 seconds
# Shimmer detected at 17.88 seconds
# Shimmer detected at 17.89 seconds
# Shimmer detected at 17.91 seconds
# Shimmer detected at 17.93 seconds
# Shimmer detected at 17.94 seconds
# Shimmer detected at 22.60 seconds
# Shimmer detected at 22.62 seconds
# Shimmer detected at 22.63 seconds
# Shimmer detected at 22.65 seconds
# Shimmer detected at 22.67 seconds
# Shimmer detected at 22.89 seconds
# Shimmer detected at 22.90 seconds
# Shimmer detected at 24.22 seconds
# Shimmer detected at 24.23 seconds
# Shimmer detected at 24.25 seconds
# Shimmer detected at 24.27 seconds
# Shimmer detected at 24.28 seconds
# Shimmer detected at 24.30 seconds
# Shimmer detected at 24.32 seconds
# Detection completed.
